# %% [markdown]
# # **Assignment 03**

# %% [markdown]
# ---

# %% [markdown]
# ## **Import External Libraries**

# %%
import numpy as np
import sympy as sp

from IPython.display import display, Math

# %% [markdown]
# ---

# %% [markdown]
# ## **2. Finding Eigenvectors Using Python**

# %%
sigmay = np.array([[0, -1j],[1j, 0]])

display(Math(f"\\sigma_y = {sp.latex(sp.Matrix(sigmay))}"))

print("---------------")

eigenvalues, eigenvectors = np.linalg.eig(sigmay)
eigenvalues = np.round(eigenvalues, 4)
eigenvectors = np.round(eigenvectors, 4)

display(Math(f"\\text{{Eigenvalues: }} {sp.latex(sp.Matrix(eigenvalues))}"))
display(Math(f"\\text{{Eigenvectors: }} {sp.latex(sp.Matrix(eigenvectors))}"))
# Out:
# $\displaystyle \sigma_y = \left[\begin{matrix}0 & - 1.0 i\\1.0 i & 0\end{matrix}\right]$
# ---------------
# $\displaystyle \text{Eigenvalues: } \left[\begin{matrix}1.0\\-1.0\end{matrix}\right]$
# $\displaystyle \text{Eigenvectors: } \left[\begin{matrix}- 0.7071 i & 0.7071\\0.7071 & - 0.7071 i\end{matrix}\right]$

# %% [markdown]
# ---

# %% [markdown]
# ## **3. Pauli Matrix Multiplication by Hand and Using Python**

# %%
sigmay = np.array([[0, -1j], [1j, 0]])

display(Math(f"\\sigma_y = {sp.latex(sp.Matrix(sigmay))}"))
display(Math(f"\\sigma_y^2 = {sp.latex(sp.Matrix(np.matmul(sigmay, sigmay)))}"))
# Out:
# $\displaystyle \sigma_y = \left[\begin{matrix}0 & - 1.0 i\\1.0 i & 0\end{matrix}\right]$
# $\displaystyle \sigma_y^2 = \left[\begin{matrix}1.0 & 0\\0 & 1.0\end{matrix}\right]$

# %% [markdown]
# ---

# %% [markdown]
# ## **4. Pauli Matrix Multiplication by Hand and Using Python**

# %%
sigmaz = np.array([[1, 0], [0, -1]])

display(Math(f"\\sigma_z = {sp.latex(sp.Matrix(sigmaz))}"))
display(Math(f"\\sigma_z^2 = {sp.latex(sp.Matrix(np.matmul(sigmaz, sigmaz)))}"))
# Out:
# $\displaystyle \sigma_z = \left[\begin{matrix}1 & 0\\0 & -1\end{matrix}\right]$
# $\displaystyle \sigma_z^2 = \left[\begin{matrix}1 & 0\\0 & 1\end{matrix}\right]$

# %% [markdown]
# ---

# %% [markdown]
# ## **5. Proof of Hermitianity**

# %%
sigmay_dagger = sigmay.conj().T
display(Math(f"\\sigma_y^{{*^T}} = {sp.latex(sp.Matrix(sigmay_dagger))}"))

print("---------------")

print(f"Check if Sigma Y is Hermitian: {np.allclose(sigmay_dagger, sigmay)}")
# Out:
# $\displaystyle \sigma_y^{*^T} = \left[\begin{matrix}0 & - 1.0 i\\1.0 i & 0\end{matrix}\right]$
# ---------------
# Check if Sigma Y is Hermitian: True

# %% [markdown]
# ---

# %% [markdown]
# ## **6. Operation of Paul Matrix on Bra and Ket**

# %%
zerospin = np.array([[1], [0]])
print("Dimension of zerospin:\n", zerospin.shape)

print("---------------")

sigma_y_zero = np.dot(sigmay, zerospin)
display(Math(f"\\sigma_y \\vert 0 \\rangle = {sp.latex(sp.Matrix(sigma_y_zero))}"))

bra_zero = zerospin.conj().T
bra_zero_sigma_y = np.dot(bra_zero, sigmay)
display(Math(f"\\langle 0 \\vert \\sigma_y = {sp.latex(sp.Matrix(bra_zero_sigma_y))}"))
# Out:
# Dimension of zerospin:
#  (2, 1)
# ---------------
# $\displaystyle \sigma_y \vert 0 \rangle = \left[\begin{matrix}0\\1.0 i\end{matrix}\right]$
# $\displaystyle \langle 0 \vert \sigma_y = \left[\begin{matrix}0 & - 1.0 i\end{matrix}\right]$

# %% [markdown]
# ---
